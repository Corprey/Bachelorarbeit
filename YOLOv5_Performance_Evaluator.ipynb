# %% [markdown]
# # Performance evaluation for YOLOv5 Network
# This script evaluates the performance of an already trained YOLOv5 Network based on the provided image set.

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate ./data.yaml
#
# # Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2, ..]
# path: ../../GTSDB  # dataset root dir
# train: ../../GTSDB/images # train images
# val: ../../GTSDB/images/val  # val images
#
# # This Path specifies which images are used to validate the training set
# test:  ../../improved_imgs/images/distorted_contrast
#
#
# # Classes (43 GTSDB classes)
# nc: 43
# names:
#   0: Speed limit (20km/h)
#   1: Speed limit (30km/h)
#   2: Speed limit (50km/h)
#   3: Speed limit (60km/h)
#   4: Speed limit (70km/h)
#   5: Speed limit (80km/h)
#   6: End of speed limit (80km/h)
#   7: Speed limit (100km/h)
#   8: Speed limit (120km/h)
#   9: No passing
#   10: No passing for vehicles over 3.5 metric tons
#   11: Right-of-way at the next intersection
#   12: Priority road
#   13: Yield
#   14: Stop
#   15: No vehicles
#   16: Vehicles over 3.5 metric tons prohibited
#   17: No entry
#   18: General caution
#   19: Dangerous curve to the left
#   20: Dangerous curve to the right
#   21: Double curve
#   22: Bumpy road
#   23: Slippery road
#   24: Road narrows on the right
#   25: Road work
#   26: Traffic signals
#   27: Pedestrians
#   28: Children crossing
#   29: Bicycles crossing
#   30: Beware of ice/snow
#   31: Wild animals crossing
#   32: End of all speed and passing limits
#   33: Turn right ahead
#   34: Turn left ahead
#   35: Ahead only
#   36: Go straight or right
#   37: Go straight or left
#   38: Keep right
#   39: Keep left
#   40: Roundabout mandatory
#   41: End of no passing
#   42: End of no passing by vehicles over 3.5 metric ton

# %%
# !python ../../YOLOv5_GTSDB/yolov5/val.py --weights ../../networks/YOLOv5s_train_withAugment_80batch_640img.pt --data ./data.yaml --img 640 --half --verbose --save-txt --save-json --task=test
# Out:
# loading annotations into memory...
# val: data=./data.yaml, weights=['../../networks/YOLOv5s_train_withAugment_80batch_640img.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=True, save_txt=True, save_hybrid=False, save_conf=False, save_json=True, project=..\..\YOLOv5_GTSDB\yolov5\runs\val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5  v7.0-175-g5f11555 Python-3.10.9 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4096MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7126096 parameters, 0 gradients, 16.1 GFLOPs
#
# test: Scanning C:\Users\phili\Documents\TU_Wien\Bachelorarbeit_C\improved_imgs\labels\distorted_contrast.cache... 506 images, 94 backgrounds, 0 corrupt: 100%|##########| 600/600 [00:00<?, ?it/s]
# ...
